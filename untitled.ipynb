# %%
from datetime import datetime

expiration_ms = 1771774050152
expiration_date = datetime.fromtimestamp(expiration_ms / 1000.0)

print(expiration_date)
# Out:
# 2026-02-22 16:27:30.152000

# %% [markdown]
# Build service given the necessary scopes

# %%
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

import os.path

SCOPES = ['https://www.googleapis.com/auth/gmail.modify']

def get_token():
    creds = None
    token = None
    if os.path.exists("gcp/token.json"):
        creds = Credentials.from_authorized_user_file("gcp/token.json", SCOPES)
        print("Token loaded from gcp/token.json")
        
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                "gcp/credentials.json", SCOPES
            )
            creds = flow.run_local_server(port=0)
            # Save the credentials for the next run
        with open("gcp/token.json", "w") as token:
            token.write(creds.to_json())
            print("Token saved to gcp/token.json")
    
    return token

get_token()
# Out:
# /home/husky/python-projects/mail-labeler/venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.14) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# Token loaded from gcp/token.json
# Token saved to gcp/token.json
# <_io.TextIOWrapper name='gcp/token.json' mode='w' encoding='UTF-8'>

# %%
service = build("gmail", "v1", credentials=Credentials.from_authorized_user_file("gcp/token.json", SCOPES))

# %% [markdown]
# Get new messages / emails

# %%
# this one fetches the first message from the list given history_id

def get_message(service, history_id):
    try:
        history_response = service.users().history().list(
            userId='me', 
            startHistoryId=history_id,
            historyTypes=['messageAdded']
        ).execute()

        changes = history_response.get('history', [])
        
        if not changes:
            print("No new emails")
            return

        for record in changes:
            added_messages = record.get('messagesAdded', [])
            
            for msg_item in added_messages:
                message_id = msg_item['message']['id']
                
                msg = service.users().messages().get(userId='me', id=message_id).execute()

                # print(f"Full message data: {msg}")
                
                headers = msg['payload']['headers']
                subject = next(h['value'] for h in headers if h['name'] == 'Subject')
                sender = next(h['value'] for h in headers if h['name'] == 'From')
                
                print(f"Email found: {subject} from {sender}")
                print(f"Message ID: {message_id}")

                parts = msg['payload'].get('parts', [])
                print(len(parts))

                for part in parts:
                    if part['mimeType'] == 'text/plain':
                        return part
                # print(f"Message payload: {msg['payload']['parts']}")

                return None
                
    except Exception as error:
        print(f'An error occurred: {error}')

temp = get_message(service, 1028201)

# print(temp)

body_data = temp['body']['data']
body_text = base64.urlsafe_b64decode(body_data).decode('utf-8')
print(body_text)
# Out:
# Email found: What to make of fibremaxxing, the latest dietary fad from The Economist Today <newsletters@e.economist.com>
# Message ID: 19c86d66328179a6
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  <link rel=stylesheet href=https://marber-cdn.economist.com/foundations/latest/css/font-face.css>
#  The Economist
#
#
#
#
#
#
#
#
#   ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌   ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌   ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌  ‌ ‌ ‌  ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌   ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌   ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌   ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌   ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# February 22nd 2026
#
#
#
#
#
#
#
#  The Economist Today
#
#
#
#  A Sunday edition of our daily newsletter
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
#
#
#
#
# Brooke Unger
#
# Senior digital editor
#
#
#
#  I thought we were all supposed to be proteinmaxxing, but apparently I was behind the times. The new trend is &ldquo;fibremaxxing&rdquo;.
#
# https://click.e.economist.com/?qs=
# Our Well Informed column
#  tells you what it is and whether you should be doing it. If you want to find out what science has to say about health and health fads, I suggest you sign up to our
#
# https://click.e.economist.com/?qs=
# Well Informed newsletter .
#
#
#
#  We&rsquo;re also paying close attention to the health of the financial markets. On the surface all seems well&mdash;but that&rsquo;s deceptive.
#
# https://click.e.economist.com/?qs=
# Our analysis
#  examines what&rsquo;s happening, and what&rsquo;s likely to happen, to assets at a time when artificial intelligence is calling into question every business model under the sun.
#
#
#
#
#  Exclusive offer: save 50%
#
#
#  Make sense of the world with The Economist.
#
# https://click.e.economist.com/?qs=%3D
# Get offer
#
#
#
#
#
#
#
#
# Editor&rsquo;s picks
#
# A selection of must-read articles
#
#
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
# Well Informed
#
# https://click.e.economist.com/?qs=%3D
# Should you be fibremaxxing?
#
# https://click.e.economist.com/?qs=%3D
# What to make of the new dietary fad
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
# Disruption and dispersion
#
# https://click.e.economist.com/?qs=%3D
# Markets are churning furiously beneath a calm surface
#
# https://click.e.economist.com/?qs=%3D
# AI is prompting investors to reassess every business model under the sun
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
# Trumped on tariffs
#
# https://click.e.economist.com/?qs=%3D
# The Supreme Court tariffs ruling reins in Donald Trump
#
# https://click.e.economist.com/?qs=%3D
# Even if he has ways to rebuild trade barriers, writes Douglas Irwin
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
# Turn that U-Haul around
#
# https://click.e.economist.com/?qs=%3D
# The Midwest’s remarkable turnaround
#
# https://click.e.economist.com/?qs=%3D
# For the first time in 70 years, more Americans are coming than going
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
# Rolling the dice
#
# https://click.e.economist.com/?qs=%3D
# Could the next big gambling destination be in the Gulf?
#
# https://click.e.economist.com/?qs=%3D
# The UAE hopes to emulate Las Vegas and Macau
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
# Auto focus
#
# https://click.e.economist.com/?qs=%3D
# Why one corner of Europe’s car industry is still booming
#
# https://click.e.economist.com/?qs=%3D
# The world’s most car-intensive economy draws plenty of investment, for now
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
# New stomping grounds
#
# https://click.e.economist.com/?qs=%3D
# The latest viral choreography craze? Line dancing
#
# https://click.e.economist.com/?qs=%3D
# It has moved from honky-tonks to urban bars
#
#
# https://click.e.economist.com/?qs=
#
# https://click.e.economist.com/?qs=
# Games
#
# https://click.e.economist.com/?qs=
# Dateline
#
# https://click.e.economist.com/?qs=
# Guess the year in which these extracts were published in  The Economist
#
#
# Podcast
#
# https://click.e.economist.com/?qs=
#
# https://click.e.economist.com/?qs=
#
# https://click.e.economist.com/?qs=
# The Weekend Intelligence
#
# https://click.e.economist.com/?qs=
# Inside Nepal&rsquo;s Gen Z Revolution
#
# https://click.e.economist.com/?qs=
# Listen
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=
#
# https://click.e.economist.com/?qs=
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=
#
# https://click.e.economist.com/?qs=
#
#
#
#
#
#
#
#
#
#
# Most read by subscribers
#
# 1
#
# https://click.e.economist.com/?qs=
# Vladimir Putin is caught in a vice of his own making
#
# 2
# https://click.e.economist.com/?qs=
# Don&rsquo;t go after the rich to fix broken budgets
# 3
#
# https://click.e.economist.com/?qs=
# Russia&rsquo;s economy has entered the death zone
#
# 4
#
# https://click.e.economist.com/?qs=
# What Andrew Mountbatten-Windsor&rsquo;s arrest means for the monarchy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
#
# https://click.e.economist.com/?qs=%3D
#
# Download our app for
# https://click.e.economist.com/?qs=
# iOS and
# https://click.e.economist.com/?qs=
# Android
#
# <a alias="" class="footerLink" conversion="false" href="https://myaccount.economist.com/s/preferences?contactId=0033z00002qetMeAAI&newslettercode=te_today" mc-deep-link="false" style="text-decoration:none;color:#ffffff;"#ffffff;text-decoration:none;color:#ffffff;" target="_blank" title="Unsubscribe">Unsubscribe</a>
# https://click.e.economist.com/?qs=%3D
# Contact us
# https://click.e.economist.com/?qs=%3D
# Update your details
#
# This email has been sent to knysakadrian@gmail.com  because you signed up for this newsletter or because it is included in your subscription.
#
#
#  Registered in England and Wales. No. 236383.
#
#  The Adelphi, 1-11 John Adam Street, London, WC2N 6HT
#
# https://click.e.economist.com/?qs=
# View email online
# https://click.e.economist.com/?qs=%3D
# Privacy Policy
# https://click.e.economist.com/?qs=%3D
# Terms & Conditions
#
#
#  Copyright (c) The Economist Newspaper Limited 2026. All rights reserved.
#
#
#
#
#  This email was sent to: knysakadrian@gmail.com
#  This email was sent by: The Economist Newspaper Ltd., The Adelphi, 1-11 John Adam Street, London, London, WC2N 6HT, GB

# %%
# body_text

import re
from bs4 import BeautifulSoup

def clean_email_body(raw_content):
    """
    Removes HTML, CSS, hidden characters, shortens URLs.
    """
    if not raw_content:
        return ""

    # html tags and css/style blocks
    soup = BeautifulSoup(raw_content, "html.parser")
    
    # <style>, <script>, and <link> tags
    for element in soup(["style", "script", "link"]):
        element.decompose()

    text = soup.get_text(separator=' ')
    text = text.replace('\u200c', '').replace('\xa0', ' ')

    # url handling
    def url_cleaner(match):
        url = match.group(0)
        if len(url) > 60:
            return "[URL]"
        return url

    # re.sub(pattern, repl, string)
    # r'https?://\S+' - either http or https followed by characters until space.
    # matched text is passed to url_cleaner
    text = re.sub(r'https?://\S+', url_cleaner, text)

    # replaces multiple newlines, spaces with a single one
    text = re.sub(r'\n\s*\n', '\n', text)
    text = re.sub(r' +', ' ', text)
    text = text.strip()

    return text

cleaned_text = clean_email_body(body_text)
print(cleaned_text)
# Out:
# The Economist
# [URL]
# February 22nd 2026
#  The Economist Today
#  A Sunday edition of our daily newsletter
# [URL]
# [URL]
# Brooke Unger
# Senior digital editor
#  I thought we were all supposed to be proteinmaxxing, but apparently I was behind the times. The new trend is “fibremaxxing”.
# [URL]
# Our Well Informed column
#  tells you what it is and whether you should be doing it. If you want to find out what science has to say about health and health fads, I suggest you sign up to our
# [URL]
# Well Informed newsletter .
#  We’re also paying close attention to the health of the financial markets. On the surface all seems well—but that’s deceptive.
# [URL]
# Our analysis
#  examines what’s happening, and what’s likely to happen, to assets at a time when artificial intelligence is calling into question every business model under the sun.
#  Exclusive offer: save 50%
#  Make sense of the world with The Economist.
# [URL]
# Get offer
# Editor’s picks
# A selection of must-read articles
# [URL]
# [URL]
# Well Informed
# [URL]
# Should you be fibremaxxing?
# [URL]
# What to make of the new dietary fad
# [URL]
# [URL]
# Disruption and dispersion
# [URL]
# Markets are churning furiously beneath a calm surface
# [URL]
# AI is prompting investors to reassess every business model under the sun
# [URL]
# [URL]
# Trumped on tariffs
# [URL]
# The Supreme Court tariffs ruling reins in Donald Trump
# [URL]
# Even if he has ways to rebuild trade barriers, writes Douglas Irwin
# [URL]
# [URL]
# Turn that U-Haul around
# [URL]
# The Midwest’s remarkable turnaround
# [URL]
# For the first time in 70 years, more Americans are coming than going
# [URL]
# [URL]
# [URL]
# [URL]
# Rolling the dice
# [URL]
# Could the next big gambling destination be in the Gulf?
# [URL]
# The UAE hopes to emulate Las Vegas and Macau
# [URL]
# [URL]
# Auto focus
# [URL]
# Why one corner of Europe’s car industry is still booming
# [URL]
# The world’s most car-intensive economy draws plenty of investment, for now
# [URL]
# [URL]
# New stomping grounds
# [URL]
# The latest viral choreography craze? Line dancing
# [URL]
# It has moved from honky-tonks to urban bars
# [URL]
# [URL]
# Games
# [URL]
# Dateline
# [URL]
# Guess the year in which these extracts were published in The Economist
# Podcast
# [URL]
# [URL]
# [URL]
# The Weekend Intelligence
# [URL]
# Inside Nepal’s Gen Z Revolution
# [URL]
# Listen
# [URL]
# [URL]
# [URL]
# [URL]
# Most read by subscribers
# 1
# [URL]
# Vladimir Putin is caught in a vice of his own making
# 2
# [URL]
# Don’t go after the rich to fix broken budgets
# 3
# [URL]
# Russia’s economy has entered the death zone
# 4
# [URL]
# What Andrew Mountbatten-Windsor’s arrest means for the monarchy
# [URL]
# [URL]
# [URL]
# [URL]
# [URL]
# Download our app for
# [URL]
# iOS and
# [URL]
# Android
#  Unsubscribe
# [URL]
# Contact us
# [URL]
# Update your details
# This email has been sent to knysakadrian@gmail.com because you signed up for this newsletter or because it is included in your subscription.
#  Registered in England and Wales. No. 236383.
#  The Adelphi, 1-11 John Adam Street, London, WC2N 6HT
# [URL]
# View email online
# [URL]
# Privacy Policy
# [URL]
# Terms & Conditions
#  Copyright (c) The Economist Newspaper Limited 2026. All rights reserved.
#  This email was sent to: knysakadrian@gmail.com
#  This email was sent by: The Economist Newspaper Ltd., The Adelphi, 1-11 John Adam Street, London, London, WC2N 6HT, GB

# %%
len(cleaned_text)
# Out:
# 3440

# %% [markdown]
# The idea is to firstly determine whether it's "safe" to send the text content of the message to an external LLM provider to categorize to avoid sending too much sensitive data :/
# To do that, we can firstly ask an LLM whether a given email (based on sender and subject) might contain some super private information.
# Also, we should (manually) check the size estimate - if the message is super large, we want to avoid send its content to an LLM provider too so we do not incur huge costs.
#
# Fields without *too much* sensitive data that we can use to filter by:
# - subject
# - from
# - size estimate
#
# What to avoid *initially*:
# - snippet (may contain temporary password reset link / reset code)
# - encoded text content
#
# If an LLM says that a given email is "safe" then we can ask it to categorize it and give it a label. If not, we want to add it a different label - like "might be sensitive". If the estimated size is super huge, we want to label it as "too large". We need to label those messages so that we avoid looping over them indifinitely.

# %%
# full workflow - option A (gcp pub/sub):

# history_id is given
# fetch message corresponding to history_id
# categorize email:
## get subject, sender, size estimate
## get text content if not too long, else get only a part of the text content.
## optionally pass to the LLM for categorization

# apply label

# possible categorization labels:
# 1. one of the following: "Unprocessable", "LLM Processed" (if error during processing, change to Unprocessable)
# 2. category label - if LLM processed, assign category label ()

def workflow_a(service, history_id):
    pass

# %%
# full workflow - option B (custom watcher script):

# script to run every 15 minutes or so
# fetch only messages from the latest timestamp (like 15-20 minutes)
# get only messages that are not labeled with "LLM Processed" or "Unprocessable"
# categorize email:
## get subject, sender, size estimate
## get text content if not too long, else get only a part of the text content.
## optionally pass to the LLM for categorization

# apply label

# possible categorization labels:
# 1. one of the following: "Unprocessable", "LLM Processed" (if error during processing, change to Unprocessable)
# 2. category label - if LLM processed, assign category label ()

def workflow_b(service, timestamp):
    pass

# %%
def get_label_map(service):
    """dictionary of {label_name: label_id}."""
    results = service.users().labels().list(userId='me').execute()
    labels = results.get('labels', [])
    
    label_map = {label['name']: label['id'] for label in labels}
    return label_map

label_map = get_label_map(service)
print(label_map)
# Out:
# {'CHAT': 'CHAT', 'SENT': 'SENT', 'INBOX': 'INBOX', 'IMPORTANT': 'IMPORTANT', 'TRASH': 'TRASH', 'DRAFT': 'DRAFT', 'SPAM': 'SPAM', 'CATEGORY_FORUMS': 'CATEGORY_FORUMS', 'CATEGORY_UPDATES': 'CATEGORY_UPDATES', 'CATEGORY_PERSONAL': 'CATEGORY_PERSONAL', 'CATEGORY_PROMOTIONS': 'CATEGORY_PROMOTIONS', 'CATEGORY_SOCIAL': 'CATEGORY_SOCIAL', 'YELLOW_STAR': 'YELLOW_STAR', 'STARRED': 'STARRED', 'UNREAD': 'UNREAD', '👹 Pilne/Ważne': 'Label_191074900200250148', '🤢 Spam': 'Label_1970431896466590113', '🎃 Do odpowiedzi': 'Label_3347196074444027717', '👽 Inne': 'Label_3725959684110416048', 'temp3 - processed': 'Label_4550656612000604041', 'temp2 - okay': 'Label_6075941912103430332', 'temp1 - not okay': 'Label_7062324791416641995', '\U0001fae5 Subskrypcje/Info/Oferty': 'Label_9020177853318762020'}

# %%
# Label_4550656612000604041

def get_new_message_ids(service, start_history_id):
    """list of message IDs added since the history_id."""
    history = service.users().history().list(
        userId='me', 
        startHistoryId=start_history_id,
        historyTypes=['messageAdded']
    ).execute()

    message_ids = []
    if 'history' in history:
        for h in history['history']:
            for msg_added in h.get('messagesAdded', []):
                message_ids.append(msg_added['message']['id'])
    
    return list(set(message_ids)) # avoid duplicates

temp_msg = get_new_message_ids(service, 1021851)

# %%
print(temp_msg)
# Out:
# ['19c71941dac0e998', '19c7679505d0c05d', '19c6cf944fa04370', '19c71905b16dfa80', '19c71ab2e4edf3db', '19c718dbbcd14ec5', '19c719cd31c68dee', '19c71aac7aa59ac0', '19c66f8258140e03', '19c6bb11873f4a12', '19c7259a716921b5', '19c6af327018c04e', '19c6874accb08f87', '19c6cd007edd3bb0', '19c7290a24af0bc8', '19c71b0ce6f9c81d', '19c673274457d682', '19c71907955190a4', '19c751f8da1dbfbb', '19c72344dc2d14f1', '19c6ff8ee06d5477', '19c6b99c36dff744', '19c728bffaadda05', '19c6aec193a00f57', '19c71a87eaf96ed4', '19c71657a78c10f2', '19c7178396c69218', '19c7688dcf655c94', '19c718d795dce1a8', '19c67ae18b9a23b3', '19c7658fed916938', '19c719368924ca3b', '19c719312503462a', '19c71bca9ff7b20f', '19c6b9a5b3c1367b', '19c707759f10850c', '19c7193c53ad2937', '19c6afb96d90ac45', '19c71777d8eca2da', '19c719f31f45f745', '19c66cfd17bb7856', '19c718d3f025a566', '19c6cecda9b931a1', '19c718e4662267be', '19c718dd462dce3e', '19c71903efed67dc', '19c71bffcbbc8981', '19c765f4b2882684', '19c720debb027ad0', '19c676de8d06a130', '19c6ffc157e24d93', '19c718e59c55d5ee', '19c718e866a07b58', '19c6aab9e4095c35', '19c71a8f5e149ebe', '19c6734dff100106', '19c718ce83dc1fef', '19c7192e10bf41bb', '19c7436162ef7787', '19c74ec847c12652', '19c7038e0b86d68c', '19c71773cdea2252', '19c718e1ce899cc6', '19c6c1c397a6db79', '19c719337a8801ae', '19c71aa4f5c76663', '19c72e5b625ace8e', '19c6c31b28d6d3f2', '19c6ad2ae8e4fb27', '19c6824dbd49f6c2', '19c66ea15704f8d1', '19c75dac846adec0', '19c6bc9b98a7c8e8', '19c719255c907000', '19c6c97843d0b7b9', '19c71a903a6b5fb8', '19c719283ca001bb', '19c6b9a4de142185', '19c6bed3974472d6', '19c719cc538271d1', '19c7213eb481cdbe', '19c753f0c6725602', '19c7193ea7bcd4b4', '19c71a084a934d77', '19c73da6b773ecbd', '19c7191775c77c9c', '19c719234c4e0009', '19c700a8c05cba2c', '19c7191f7e9c804b', '19c71938dd6f3549', '19c7032d54e178a6', '19c719199cce14af', '19c7191b65b95e94', '19c72159b11c149f', '19c711714fdcd4e6', '19c718efe2a83c19', '19c7193d0eb18386', '19c69715ffe10439', '19c6b99d3ad6c1e9', '19c7098de245534d']

# %%
msg = service.users().messages().get(userId='me', id='19c72344dc2d14f1').execute()

msg.get('labelIds', [])
# Out:
# ['UNREAD', 'Label_6075941912103430332', 'Label_4550656612000604041']

# %%
def fetch_if_not_processed(service, message_id, ai_label_id):
    """Fetches message if it doesn't have the AI_PROCESSED label."""
    msg = service.users().messages().get(userId='me', id=message_id).execute()
    
    # Check current labels
    current_labels = msg.get('labelIds', [])
    print(current_labels)
    if ai_label_id in current_labels:
        return None # Already processed
    
    # Extract snippet for LLM
    subject = next(h['value'] for h in msg['payload']['headers'] if h['name'] == 'Subject')
    snippet = msg.get('snippet', '')
    
    return {'id': message_id, 'text': f"Subject: {subject}\nContent: {snippet}"}

fetch_if_not_processed(service, '19c72344dc2d14f1', 'Label_4550656612000604041')
# Out:
# ['UNREAD', 'INBOX']
# {'id': '19c72344dc2d14f1',
#  'text': 'Subject: Spotify Head of HR JAPAC & SAMEA recently posted\nContent: After 10.5 incredible years, I&#39;ve made the decision to step away from Spotify… ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏'}

# %%
def process_and_categorize(service, message_id, ai_label_id, category_label_id):

    body = {
        'addLabelIds': [ai_label_id, category_label_id],
        'removeLabelIds': ['INBOX'] # Archive it once sorted
    }
    
    service.users().messages().modify(
        userId='me', 
        id=message_id, 
        body=body
    ).execute()

process_and_categorize(service, '19c72344dc2d14f1', 'Label_4550656612000604041', 'Label_6075941912103430332')
